# %%
from IPython.display import display_html
from vispy.color.colormap import get_colormap

display_html(get_colormap('hsl'))
display_html(get_colormap('husl'))
display_html(get_colormap('diverging'))
display_html(get_colormap('coolwarm'))
display_html(get_colormap('PuGr'))
display_html(get_colormap('GrBu'))
display_html(get_colormap('GrBu_d'))
display_html(get_colormap('RdBu'))
display_html(get_colormap('light_blues'))
display_html(get_colormap('orange'))
display_html(get_colormap('cubehelix'))
# Out:
#                 <style>
#                     table.vispy_colormap {
#                         height: 30px;
#                         border: 0;
#                         margin: 0;
#                         padding: 0;
#                     }
#
#                     table.vispy_colormap td {
#                         width: 3px;
#                         border: 0;
#                         margin: 0;
#                         padding: 0;
#                     }
#                 </style>
#                 <table class="vispy_colormap">
#                 <td style="background-color: #ff0000;"
#                                  title="#ff0000"></td>
# <td style="background-color: #ff0c00;"
#                                  title="#ff0c00"></td>
# <td style="background-color: #ff1900;"
#                                  title="#ff1900"></td>
# <td style="background-color: #ff2600;"
#                                  title="#ff2600"></td>
# <td style="background-color: #ff3300;"
# ...
